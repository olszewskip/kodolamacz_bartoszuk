# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pierwsza ramka danych

# %%
ramka1 = pd.DataFrame({"A": np.round(np.random.uniform(0,1,5),2),
                      "B": ["k", None, "k", "m", "k"],
                      "C": [False, True, True, False, False]})

# %%
ramka1
# Out:
#       A     B      C
# 0  0.17     k  False
# 1  0.27  None   True
# 2  0.48     k   True
# 3  0.79     m  False
# 4  0.43     k  False

# %%
pd.set_option("display.notebook_repr_html", True)

# %%
ramka1
# Out:
#       A     B      C
# 0  0.17     k  False
# 1  0.27  None   True
# 2  0.48     k   True
# 3  0.79     m  False
# 4  0.43     k  False

# %%
pd.set_option("display.notebook_repr_html", False)

# %%
ramka1
# Out:
#       A     B      C
# 0  0.17     k  False
# 1  0.27  None   True
# 2  0.48     k   True
# 3  0.79     m  False
# 4  0.43     k  False

# %%
pd.set_option("display.notebook_repr_html", True)
ramka1
# Out:
#       A     B      C
# 0  0.17     k  False
# 1  0.27  None   True
# 2  0.48     k   True
# 3  0.79     m  False
# 4  0.43     k  False

# %%
import seaborn as sns

# %%
flights = sns.load_dataset("flights")

# %%
iris = sns.load_dataset("iris")

# %%
sns.get_dataset_names()
# Out:
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/kodolamacz/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# ### W out myszą raz, to będziemy mogli zawijać okienko, wygodniej

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
ramka1.shape
# Out:
# (5, 3)

# %%
flights.shape
# Out:
# (144, 3)

# %%
ramka1.size
# Out:
# 15

# %%
len(ramka1)
# Out:
# 5

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.head(8)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121
# 5  1949      June         135
# 6  1949      July         148
# 7  1949    August         148

# %%
flights.tail(3)
# Out:
#      year     month  passengers
# 141  1960   October         461
# 142  1960  November         390
# 143  1960  December         432

# %%
ramka1
# Out:
#       A     B      C
# 0  0.17     k  False
# 1  0.27  None   True
# 2  0.48     k   True
# 3  0.79     m  False
# 4  0.43     k  False

# %%
ramka1.dtypes
# Out:
# A    float64
# B     object
# C       bool
# dtype: object

# %%
# eksperyment
ramka1 = pd.DataFrame({"A": np.round(np.random.uniform(0,1,5),2),
                      "B": ["k", "k", "k", "m", "k"],
                      "C": [False, True, True, False, False]})
ramka1.dtypes
# Out:
# A    float64
# B     object
# C       bool
# dtype: object

# %%
ramka1 = pd.DataFrame({"A": np.round(np.random.uniform(0,1,5),2),
                      "B": ["k", None, "k", "m", "k"],
                      "C": [False, True, True, False, False]})
ramka1.B.values
# Out:
# array(['k', None, 'k', 'm', 'k'], dtype=object)

# %%
ramka1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
# A    5 non-null float64
# B    4 non-null object
# C    5 non-null bool
# dtypes: bool(1), float64(1), object(1)
# memory usage: 165.0+ bytes

# %%
ramka1.fillna("wstawiam")
# Out:
#       A         B      C
# 0  0.32         k  False
# 1  0.99  wstawiam   True
# 2  0.51         k   True
# 3  0.64         m  False
# 4  0.12         k  False

# %%
ramka1.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False

# %%
pd.isnull(np.NaN)
# Out:
# True

# %% [markdown]
# # Wybór kolumn

# %%
# 1 sposob
ramka1["A"]
# Out:
# 0    0.32
# 1    0.99
# 2    0.51
# 3    0.64
# 4    0.12
# Name: A, dtype: float64

# %%
type(ramka1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ramka1["A"])
# Out:
# pandas.core.series.Series

# %%
# 2 sposob
ramka1.get("A")
# Out:
# 0    0.32
# 1    0.99
# 2    0.51
# 3    0.64
# 4    0.12
# Name: A, dtype: float64

# %%
# 3 sposob
ramka1.A
# Out:
# 0    0.32
# 1    0.99
# 2    0.51
# 3    0.64
# 4    0.12
# Name: A, dtype: float64

# %%
ramka1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
ramka1["columns"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'columns'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.DataFrame(ramka1.A)
# Out:
#       A
# 0  0.32
# 1  0.99
# 2  0.51
# 3  0.64
# 4  0.12

# %%
pd.Series(np.r_[np.nan, 0:1:4j])
# Out:
# 0         NaN
# 1    0.000000
# 2    0.333333
# 3    0.666667
# 4    1.000000
# dtype: float64

# %%
#typ Series, kolumna
ramka1.A
# Out:
# 0    0.32
# 1    0.99
# 2    0.51
# 3    0.64
# 4    0.12
# Name: A, dtype: float64

# %%
#typ Numpy
ramka1.A.values
# Out:
# array([ 0.32,  0.99,  0.51,  0.64,  0.12])

# %% [markdown]
# # typy czasowe

# %%
pd.Series(pd.date_range("2018-07-07", periods=3))
# Out:
# 0   2018-07-07
# 1   2018-07-08
# 2   2018-07-09
# dtype: datetime64[ns]

# %%
pd.Series(pd.date_range("2018-07-07", periods=3, freq="12H"))
# Out:
# 0   2018-07-07 00:00:00
# 1   2018-07-07 12:00:00
# 2   2018-07-08 00:00:00
# dtype: datetime64[ns]

# %% [markdown]
# # Typy kategoryczne

# %%
flights.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
ramka1
# Out:
#       A     B      C
# 0  0.32     k  False
# 1  0.99  None   True
# 2  0.51     k   True
# 3  0.64     m  False
# 4  0.12     k  False

# %%
ramka1.dtypes
# Out:
# A    float64
# B     object
# C       bool
# dtype: object

# %%
pd.Series(ramka1.B, dtype="category")
# Out:
# 0      k
# 1    NaN
# 2      k
# 3      m
# 4      k
# Name: B, dtype: category
# Categories (2, object): [k, m]

# %%
ramka1.B.astype("category")
# Out:
# 0      k
# 1    NaN
# 2      k
# 3      m
# 4      k
# Name: B, dtype: category
# Categories (2, object): [k, m]

# %%
innaKategoryczna = pd.Series(pd.Categorical(["a", "b", "c", "a"], categories=["a", "b", "c", "d"]))
innaKategoryczna
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: category
# Categories (4, object): [a, b, c, d]

# %%
innaKategoryczna = pd.Series(pd.Categorical(["a", "b", "c", "a"], 
                                            categories=[ "c","a", "b", "d"], 
                                            ordered=True))
innaKategoryczna
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: category
# Categories (4, object): [c < a < b < d]

# %%
innaKategoryczna.sort_values()
# Out:
# 2    c
# 0    a
# 3    a
# 1    b
# dtype: category
# Categories (4, object): [c < a < b < d]

# %%
innaKategoryczna
# Out:
# 2    c
# 0    a
# 3    a
# 1    b
# dtype: category
# Categories (4, object): [c < a < b < d]

# %%
innaKategoryczna <= "a"
# Out:
# 2     True
# 0     True
# 3     True
# 1    False
# dtype: bool

# %%
ramka1.A.values
# Out:
# array([ 0.32,  0.99,  0.51,  0.64,  0.12])

# %%
pd.cut(ramka1.A.values, np.r_[0, 0.25, 0.4, 0.7, 1])
# Out:
# [(0.25, 0.4], (0.7, 1], (0.4, 0.7], (0.4, 0.7], (0, 0.25]]
# Categories (4, object): [(0, 0.25] < (0.25, 0.4] < (0.4, 0.7] < (0.7, 1]]

# %%
pd.cut(ramka1.A.values,
       np.r_[0, 0.25, 0.4, 0.7, 1],
       right=False,
       labels=["et1", "et2", "et3", "et4"])
# Out:
# [et2, et4, et3, et3, et1]
# Categories (4, object): [et1 < et2 < et3 < et4]

# %%
innaKategoryczna
# Out:
# 2    c
# 0    a
# 3    a
# 1    b
# dtype: category
# Categories (4, object): [c < a < b < d]

# %%
innaKategoryczna.cat.codes
# Out:
# 2    0
# 0    1
# 3    1
# 1    2
# dtype: int8

# %%
innaKategoryczna.cat.categories
# Out:
# Index(['c', 'a', 'b', 'd'], dtype='object')

# %%
innaKategoryczna.cat.categories = ["maly", "sredni", "duzy", "olbrzymi"]

# %%
innaKategoryczna
# Out:
# 2      maly
# 0    sredni
# 3    sredni
# 1      duzy
# dtype: category
# Categories (4, object): [maly < sredni < duzy < olbrzymi]

# %%
innaKategoryczna[0] = "duzy"
innaKategoryczna
# Out:
# 2      maly
# 0      duzy
# 3    sredni
# 1      duzy
# dtype: category
# Categories (4, object): [maly < sredni < duzy < olbrzymi]

# %%
innaKategoryczna[0] = "malutki"
innaKategoryczna
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-656b656724f8> in <module>()
# ----> 1 innaKategoryczna[0] = "malutki"
#       2 innaKategoryczna
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     771         # do the setitem
#     772         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 773         setitem(key, value)
#     774         if cacher_needs_updating:
#     775             self._maybe_update_cacher()
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in setitem(key, value)
#     767                     pass
#     768
# --> 769             self._set_with(key, value)
#     770
#     771         # do the setitem
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _set_with(self, key, value)
# ...

# %%
innaKategoryczna = innaKategoryczna.cat.add_categories("malutki")
innaKategoryczna[0] = "malutki"
innaKategoryczna
# Out:
# 2       maly
# 0    malutki
# 3     sredni
# 1       duzy
# dtype: category
# Categories (5, object): [maly < sredni < duzy < olbrzymi < malutki]

# %%
innaKategoryczna = innaKategoryczna.cat.reorder_categories(["malutki","maly","sredni","duzy","olbrzymi"], ordered=True)
innaKategoryczna
# Out:
# 2       maly
# 0    malutki
# 3     sredni
# 1       duzy
# dtype: category
# Categories (5, object): [malutki < maly < sredni < duzy < olbrzymi]

# %%
innaKategoryczna.cat.ordered
# Out:
# True

# %% [markdown]
# # Indeksy

# %%
ramka1
# Out:
#       A     B      C
# 0  0.32     k  False
# 1  0.99  None   True
# 2  0.51     k   True
# 3  0.64     m  False
# 4  0.12     k  False

# %%
ramka1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ramka1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
ramka1.A.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ramka1.columns = ["a", "b", "c"]
ramka1
# Out:
#       a     b      c
# 0  0.32     k  False
# 1  0.99  None   True
# 2  0.51     k   True
# 3  0.64     m  False
# 4  0.12     k  False

# %%
ramka2 = ramka1.set_index(np.linspace(0, 1, 5))
ramka2
# Out:
#          a     b      c
# 0.00  0.32     k  False
# 0.25  0.99  None   True
# 0.50  0.51     k   True
# 0.75  0.64     m  False
# 1.00  0.12     k  False

# %%
ramka2.index
# Out:
# Float64Index([0.0, 0.25, 0.5, 0.75, 1.0], dtype='float64')

# %%
ramka2.index = np.r_[7:12]
ramka2
# Out:
#        a     b      c
# 7   0.32     k  False
# 8   0.99  None   True
# 9   0.51     k   True
# 10  0.64     m  False
# 11  0.12     k  False

# %%
ramka2.index
# Out:
# Int64Index([7, 8, 9, 10, 11], dtype='int64')

# %%
ramka1.index.name = "Wiersze"
ramka1.columns.name = "Kolumny"
ramka1
# Out:
# Kolumny     a     b      c
# Wiersze
# 0        0.32     k  False
# 1        0.99  None   True
# 2        0.51     k   True
# 3        0.64     m  False
# 4        0.12     k  False

# %%
ramka1.to_latex()
# Out:
# '\\begin{tabular}{lrll}\n\\toprule\nKolumny &     a &     b &      c \\\\\nWiersze &       &       &        \\\\\n\\midrule\n0       &  0.32 &     k &  False \\\\\n1       &  0.99 &  None &   True \\\\\n2       &  0.51 &     k &   True \\\\\n3       &  0.64 &     m &  False \\\\\n4       &  0.12 &     k &  False \\\\\n\\bottomrule\n\\end{tabular}\n'

# %% [markdown]
# ## indeksy wielopoziomowe (multiindex)

# %%
ramka2 = pd.DataFrame({"A" : np.round(np.random.uniform(0,1,6),2)})
ramka2
# Out:
#       A
# 0  0.15
# 1  0.80
# 2  0.19
# 3  0.06
# 4  0.92
# 5  0.48

# %%
ramka2.index = pd.MultiIndex(levels = [["x", "y", "z"], [1,2,3,4]],
                             labels = [[0,0,0,1,1,2], [0,1,3,0,1,2]],
                             names = ["i1", "i2"])
ramka2
# Out:
#           A
# i1 i2
# x  1   0.15
#    2   0.80
#    4   0.19
# y  1   0.06
#    2   0.92
# z  3   0.48

# %%
ramka2.loc["x",1]
# Out:
# A    0.15
# Name: (x, 1), dtype: float64

# %%
ramka2.loc["x"]
# Out:
#        A
# i2
# 1   0.15
# 2   0.80
# 4   0.19

# %% [markdown]
# # wybór po indeksie wierszy, indeksowanie

# %%
b = pd.Series(np.round(np.random.uniform(0,1,10),2))
i = np.r_[0:10]
np.random.shuffle(i)
b.index = i
b
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# 9    0.02
# 7    0.33
# 2    0.56
# 1    0.36
# 0    0.31
# 5    0.94
# 4    0.63
# dtype: float64

# %%
c = b.copy()
c.index=["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
c
# Out:
# a    0.42
# b    0.74
# c    0.50
# d    0.32
# e    0.61
# f    0.14
# g    0.14
# h    0.33
# i    0.74
# j    0.15
# dtype: float64

# %%
b[0:1]
# Out:
# 6    0.97
# dtype: float64

# %%
b[0:3]
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# dtype: float64

# %%
b[b > 0.45]
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# 2    0.56
# 5    0.94
# 4    0.63
# dtype: float64

# %%
b
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# 9    0.02
# 7    0.33
# 2    0.56
# 1    0.36
# 0    0.31
# 5    0.94
# 4    0.63
# dtype: float64

# %%
b[0]
# Out:
# 0.31

# %%
c
# Out:
# a    0.42
# b    0.74
# c    0.50
# d    0.32
# e    0.61
# f    0.14
# g    0.14
# h    0.33
# i    0.74
# j    0.15
# dtype: float64

# %%
c[0]
# Out:
# 0.41999999999999998

# %%
c["h"]
# Out:
# 0.33000000000000002

# %%
b[[0,1]]
# Out:
# 0    0.31
# 1    0.36
# dtype: float64

# %%
c[[0,1]]
# Out:
# a    0.42
# b    0.74
# dtype: float64

# %%
b
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# 9    0.02
# 7    0.33
# 2    0.56
# 1    0.36
# 0    0.31
# 5    0.94
# 4    0.63
# dtype: float64

# %%
# numer porządkowy
b.iloc[0]
# Out:
# 0.96999999999999997

# %%
c.iloc[0]
# Out:
# 0.41999999999999998

# %%
c.iloc["c"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-ed540493c18a> in <module>()
# ----> 1 c.iloc["c"]
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1619
#    1620             else:
# -> 1621                 key = self._convert_scalar_indexer(key, axis)
#    1622
#    1623                 if not is_integer(key):
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
# ...

# %%
#indeks
b.loc[0]
# Out:
# 0.31

# %%
c.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-684299d268f7> in <module>()
# ----> 1 c.loc[0]
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1480
#    1481         # fall thru to straight lookup
# -> 1482         self._has_valid_type(key, axis)
#    1483         return self._get_label(key, axis=axis)
#    1484
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1407
#    1408             try:
# ...

# %%
b
# Out:
# 6    0.97
# 8    0.72
# 3    0.94
# 9    0.02
# 7    0.33
# 2    0.56
# 1    0.36
# 0    0.31
# 5    0.94
# 4    0.63
# dtype: float64

# %%
#indeksów
b.loc[8:2]
# Out:
# 8    0.72
# 3    0.94
# 9    0.02
# 7    0.33
# 2    0.56
# dtype: float64

# %%
#numer porządkowy
b[8:2]
# Out:
# Series([], dtype: float64)

# %%
c.loc["a":"c"]
# Out:
# a    0.42
# b    0.74
# c    0.50
# dtype: float64

# %%
c["a":"c"]
# Out:
# a    0.42
# b    0.74
# c    0.50
# dtype: float64

# %%
ramka2
# Out:
#           A
# i1 i2
# x  1   0.15
#    2   0.80
#    4   0.19
# y  1   0.06
#    2   0.92
# z  3   0.48

# %%
ramka2.A.loc["x"]
# Out:
# i2
# 1    0.15
# 2    0.80
# 4    0.19
# Name: A, dtype: float64

# %%
ramka2.A["x"]
# Out:
# i2
# 1    0.15
# 2    0.80
# 4    0.19
# Name: A, dtype: float64

# %%
ramka2.A.loc[:,1]
# Out:
# i1
# x    0.15
# y    0.06
# Name: A, dtype: float64

# %%
ramka2.A.loc["x",1]
# Out:
# 0.14999999999999999

# %%
ramka2.A.loc[["x","z"],[1,3]]
# Out:
# i1  i2
# x   1     0.15
# z   3     0.48
# Name: A, dtype: float64

# %%
iris[["sepal_width", "petal_width"]].head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
iris.iloc[0:4:2, :]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# # losowe podzbiory

# %%
ramka2.sample(n=2)
# Out:
#           A
# i1 i2
# x  1   0.15
# y  1   0.06

# %%
ramka2.sample(frac=0.4)
# Out:
#           A
# i1 i2
# z  3   0.48
# y  2   0.92

# %% [markdown]
# # dodawanie wierszy/kolumn

# %%
ramka2["B"] = 2*ramka2.A+1
ramka2
# Out:
#           A     B
# i1 i2
# x  1   0.15  1.30
#    2   0.80  2.60
#    4   0.19  1.38
# y  1   0.06  1.12
#    2   0.92  2.84
# z  3   0.48  1.96

# %%
ramka2 = ramka2.drop("B", axis=1)
ramka2
# Out:
#           A
# i1 i2
# x  1   0.15
#    2   0.80
#    4   0.19
# y  1   0.06
#    2   0.92
# z  3   0.48

# %%
ramka1
# Out:
# Kolumny     a     b      c
# Wiersze
# 0        0.32     k  False
# 1        0.99  None   True
# 2        0.51     k   True
# 3        0.64     m  False
# 4        0.12     k  False

# %%
ramka1.loc[8] = [0.77, "m", True]
ramka1
# Out:
# Kolumny     a     b      c
# Wiersze
# 0        0.32     k  False
# 1        0.99  None   True
# 2        0.51     k   True
# 3        0.64     m  False
# 4        0.12     k  False
# 8        0.77     m   True

# %%
ramka1 = ramka1.drop(8, axis=0)
ramka1
# Out:
# Kolumny     a     b      c
# Wiersze
# 0        0.32     k  False
# 1        0.99  None   True
# 2        0.51     k   True
# 3        0.64     m  False
# 4        0.12     k  False

# %%
np.exp(ramka1.a)
# Out:
# Wiersze
# 0    1.377128
# 1    2.691234
# 2    1.665291
# 3    1.896481
# 4    1.127497
# Name: a, dtype: float64

# %% [markdown]
# # statystyki opisowe

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips.sex.describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
tips.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
#jasno zaznaczamy, że chodzi o kolumny, może być krotka () a może lista []
tips.loc[:,("smoker", "total_bill", "tip")].head()
# Out:
#   smoker  total_bill   tip
# 0     No       16.99  1.01
# 1     No       10.34  1.66
# 2     No       21.01  3.50
# 3     No       23.68  3.31
# 4     No       24.59  3.61

# %%
tips[["smoker", "total_bill", "tip"]]
# Out:
#     smoker  total_bill   tip
# 0       No       16.99  1.01
# 1       No       10.34  1.66
# 2       No       21.01  3.50
# 3       No       23.68  3.31
# 4       No       24.59  3.61
# 5       No       25.29  4.71
# 6       No        8.77  2.00
# 7       No       26.88  3.12
# 8       No       15.04  1.96
# 9       No       14.78  3.23
# 10      No       10.27  1.71
# 11      No       35.26  5.00
# 12      No       15.42  1.57
# 13      No       18.43  3.00
# 14      No       14.83  3.02
# 15      No       21.58  3.92
# 16      No       10.33  1.67
# 17      No       16.29  3.71
# 18      No       16.97  3.50
# 19      No       20.65  3.35
# 20      No       17.92  4.08
# 21      No       20.29  2.75
# 22      No       15.77  2.23
# 23      No       39.42  7.58
# 24      No       19.82  3.18
# 25      No       17.81  2.34
# 26      No       13.37  2.00
# 27      No       12.69  2.00
# 28      No       21.70  4.30
# 29      No       19.65  3.00
# ..     ...         ...   ...
# ...

# %% [markdown]
# ### tabele przestawne

# %%
pd.pivot_table(tips[["smoker", "total_bill", "tip"]],
               index=["smoker"],
               aggfunc="mean"
              )
# Out:
#              tip  total_bill
# smoker
# Yes     3.008710   20.756344
# No      2.991854   19.188278

# %%
pd.pivot_table(tips,
               index=["smoker", "sex"],
               aggfunc="mean"
              )
# Out:
#                    size       tip  total_bill
# smoker sex
# Yes    Male    2.500000  3.051167   22.284500
#        Female  2.242424  2.931515   17.977879
# No     Male    2.711340  3.113402   19.791237
#        Female  2.592593  2.773519   18.105185

# %%
pd.pivot_table(tips,
               index=["smoker", "sex"], 
                columns=["day"],
               aggfunc="mean"
              )
# Out:
#               total_bill                                      tip            \
# day                 Thur        Fri        Sat        Sun    Thur       Fri
# smoker sex
# Yes    Male    19.171000  20.452500  21.837778  26.141333  3.0580  2.741250
#        Female  19.218571  12.654286  20.266667  16.540000  2.9900  2.682857
# No     Male    18.486500  17.475000  19.929063  20.403256  2.9415  2.500000
#        Female  16.014400  19.365000  19.003846  20.824286  2.4596  3.125000
#
#                                        size
# day                 Sat       Sun      Thur    Fri       Sat       Sun
# smoker sex
# Yes    Male    2.879259  3.521333  2.300000  2.125  2.629630  2.600000
#        Female  2.868667  3.500000  2.428571  2.000  2.200000  2.500000
# No     Male    3.256563  3.115349  2.500000  2.000  2.656250  2.883721
#        Female  2.724615  3.329286  2.480000  2.500  2.307692  3.071429

# %%
flights.groupby("year").mean().head()
# Out:
#       passengers
# year
# 1949  126.666667
# 1950  139.666667
# 1951  170.166667
# 1952  197.000000
# 1953  225.000000

# %%
flights.groupby("year").sum().head()
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700

# %%
pd.pivot_table(flights,
               index=["year"], 
               aggfunc="sum"
              )
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
tips.groupby(["smoker","sex"]).mean()
# Out:
#                total_bill       tip      size
# smoker sex
# Yes    Male     22.284500  3.051167  2.500000
#        Female   17.977879  2.931515  2.242424
# No     Male     19.791237  3.113402  2.711340
#        Female   18.105185  2.773519  2.592593

# %% [markdown]
# ### tabele kontyngencji

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
pd.crosstab(tips.smoker, tips.sex)
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
pd.crosstab(tips.smoker, [tips.sex,tips.day])
# Out:
# sex    Male             Female
# day    Thur Fri Sat Sun   Thur Fri Sat Sun
# smoker
# Yes      10   8  27  15      7   7  15   4
# No       20   2  32  43     25   2  13  14

# %%
tips.sort_values(by="tip")
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 215       12.90   1.10  Female    Yes   Sat  Dinner     2
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 235       10.07   1.25    Male     No   Sat  Dinner     2
# 75        10.51   1.25    Male     No   Sat  Dinner     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 43         9.68   1.32    Male     No   Sun  Dinner     2
# 146       18.64   1.36  Female     No  Thur   Lunch     3
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2
# 195        7.56   1.44    Male     No  Thur   Lunch     2
# 30         9.55   1.45    Male     No   Sat  Dinner     2
# ...

# %%
tips.sort_values(by="tip", ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# ...

# %%
tips.sort_values(by=["smoker", "size"], ascending=[False, True])
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 82        10.07   1.83  Female     No  Thur   Lunch     1
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# 15        21.58   3.92    Male     No   Sun  Dinner     2
# 20        17.92   4.08    Male     No   Sat  Dinner     2
# 21        20.29   2.75  Female     No   Sat  Dinner     2
# 22        15.77   2.23  Female     No   Sat  Dinner     2
# 24        19.82   3.18    Male     No   Sat  Dinner     2
# ...

# %%
tips.sort_values(by=["size", "smoker"], ascending=[False, True])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 63        18.29  3.76    Male    Yes   Sat  Dinner     4
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# ...

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.sex.head()
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# Name: sex, dtype: category
# Categories (2, object): [Male, Female]

# %%
tips.sex.cat.codes
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     1
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     0
# 21     1
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 214    1
# 215    1
# 216    0
# 217    0
# 218    0
# 219    1
# 220    0
# 221    1
# 222    0
# 223    1
# 224    0
# 225    1
# 226    1
# 227    0
# 228    0
# 229    1
# 230    0
# 231    0
# 232    0
# 233    0
# 234    0
# 235    0
# 236    0
# 237    0
# 238    1
# 239    0
# 240    1
# 241    0
# 242    0
# 243    1
# dtype: int8

# %%
tips.sort_values(by=["sex", "smoker"], ascending=[True, True])
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4
# 58        11.24   1.76    Male    Yes   Sat  Dinner     2
# 60        20.29   3.21    Male    Yes   Sat  Dinner     2
# 61        13.81   2.00    Male    Yes   Sat  Dinner     2
# 62        11.02   1.98    Male    Yes   Sat  Dinner     2
# 63        18.29   3.76    Male    Yes   Sat  Dinner     4
# 69        15.01   2.09    Male    Yes   Sat  Dinner     2
# 76        17.92   3.08    Male    Yes   Sat  Dinner     2
# 80        19.44   3.00    Male    Yes  Thur   Lunch     2
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 96        27.28   4.00    Male    Yes   Fri  Dinner     2
# 97        12.03   1.50    Male    Yes   Fri  Dinner     2
# 98        21.01   3.00    Male    Yes   Fri  Dinner     2
# ...

# %%
flights.pivot("month", "year", "passengers")
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...
