# %%
import numpy as np
import pandas as pd
import sqlite3
import os

# %%
planes = pd.read_csv("/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13_planes.csv.gz", comment="#") #, compression="gzip")
airlines = pd.read_csv("/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13_airlines.csv.gz", comment="#") #, compression="gzip")
flights = pd.read_csv("/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13_flights.csv.gz", comment="#") #, compression="gzip")
airports = pd.read_csv("/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13_airports.csv.gz", comment="#") #, compression="gzip")
weather = pd.read_csv("/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13_weather.csv.gz", comment="#") #, compression="gzip")

# %%
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
os.getcwd()
# Out:
# '/home/kodolamacz/bootcamp-2018-06/Pandas'

# %%
os.path.join("katalog1", "katalog2")
# Out:
# 'katalog1/katalog2'

# %%
db_name = 'nycflights13.db'
os.path.join(os.getcwd(), db_name)
# Out:
# '/home/kodolamacz/bootcamp-2018-06/Pandas/nycflights13.db'

# %%
db_name = 'nycflights13.db'
con = sqlite3.connect(os.path.join(os.getcwd(), db_name)) # tylko się łączymy

# %%
db_name = 'nycflights13.db'
os.remove(os.path.join(os.getcwd(), db_name)) # w razie czego

# %%
db_name = 'nycflights13.db'
con = sqlite3.connect(os.path.join(os.getcwd(), db_name))

planes.to_sql("planes", con)
airlines.to_sql("airlines", con)
flights.to_sql("flights", con)
airports.to_sql("airports", con)
weather.to_sql("weather", con)

# %%
db_name = 'nycflights13.db'
con = sqlite3.connect(os.path.join(os.getcwd(), db_name))

planes.to_sql("planes", con)
airlines.to_sql("airlines", con)
flights.to_sql("flights", con)
airports.to_sql("airports", con)
weather.to_sql("weather", con)

# %% [markdown]
# ## 1

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT engine FROM planes", con)
sql_result
# Out:
#           engine
# 0      Turbo-fan
# 1      Turbo-jet
# 2  Reciprocating
# 3        4 Cycle
# 4    Turbo-shaft
# 5     Turbo-prop

# %%
pd.DataFrame({"engine": planes.engine.unique()})
# Out:
#           engine
# 0      Turbo-fan
# 1      Turbo-jet
# 2  Reciprocating
# 3        4 Cycle
# 4    Turbo-shaft
# 5     Turbo-prop

# %%
pd.DataFrame(planes.engine.unique(), columns = ["engine"])
# Out:
#           engine
# 0      Turbo-fan
# 1      Turbo-jet
# 2  Reciprocating
# 3        4 Cycle
# 4    Turbo-shaft
# 5     Turbo-prop

# %% [markdown]
# ## 2

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type, manufacturer, model, seats, engine FROM planes",
                               con)
sql_result
# Out:
#                          type                   manufacturer  \
# 0     Fixed wing multi engine                        EMBRAER
# 1     Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     Fixed wing multi engine                        EMBRAER
# 3     Fixed wing multi engine                         BOEING
# 4     Fixed wing multi engine                         BOEING
# 5     Fixed wing multi engine                         BOEING
# 6     Fixed wing multi engine                         AIRBUS
# 7     Fixed wing multi engine                 BOMBARDIER INC
# 8     Fixed wing multi engine                         BOEING
# 9     Fixed wing multi engine                         BOEING
# 10    Fixed wing multi engine                         BOEING
# 11    Fixed wing multi engine                         AIRBUS
# 12    Fixed wing multi engine               AIRBUS INDUSTRIE
# 13    Fixed wing multi engine                         BOEING
# ...

# %%
planes[["type", "manufacturer", "model", "seats", "engine"]]\
            .drop_duplicates().reset_index(drop=True)
# Out:
#                          type                   manufacturer  \
# 0     Fixed wing multi engine                        EMBRAER
# 1     Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     Fixed wing multi engine                        EMBRAER
# 3     Fixed wing multi engine                         BOEING
# 4     Fixed wing multi engine                         BOEING
# 5     Fixed wing multi engine                         BOEING
# 6     Fixed wing multi engine                         AIRBUS
# 7     Fixed wing multi engine                 BOMBARDIER INC
# 8     Fixed wing multi engine                         BOEING
# 9     Fixed wing multi engine                         BOEING
# 10    Fixed wing multi engine                         BOEING
# 11    Fixed wing multi engine                         AIRBUS
# 12    Fixed wing multi engine               AIRBUS INDUSTRIE
# 13    Fixed wing multi engine                         BOEING
# ...

# %% [markdown]
# ## 3

# %%
sql_result = pd.read_sql_query("SELECT COUNT(*), engine FROM planes GROUP BY engine", con)
sql_result
# Out:
#    COUNT(*)         engine
# 0         2        4 Cycle
# 1        28  Reciprocating
# 2      2750      Turbo-fan
# 3       535      Turbo-jet
# 4         2     Turbo-prop
# 5         5    Turbo-shaft

# %%
result = planes.engine.value_counts().reset_index()
result.columns = ["engine","COUNT(*)"]
result = result[["COUNT(*)", "engine"]]
result
# Out:
#    COUNT(*)         engine
# 0      2750      Turbo-fan
# 1       535      Turbo-jet
# 2        28  Reciprocating
# 3         5    Turbo-shaft
# 4         2        4 Cycle
# 5         2     Turbo-prop

# %%
result.equals(sql_result)
# Out:
# False

# %%
pd.DataFrame(planes.engine.value_counts()).reset_index().sort_values(by="index", ascending=False)
# Out:
#            index  engine
# 3    Turbo-shaft       5
# 5     Turbo-prop       2
# 1      Turbo-jet     535
# 0      Turbo-fan    2750
# 2  Reciprocating      28
# 4        4 Cycle       2

# %%
planes.groupby("engine").count()["seats"]
# Out:
# engine
# 4 Cycle             2
# Reciprocating      28
# Turbo-fan        2750
# Turbo-jet         535
# Turbo-prop          2
# Turbo-shaft         5
# Name: seats, dtype: int64

# %%
planes.groupby("engine").size()
# Out:
# engine
# 4 Cycle             2
# Reciprocating      28
# Turbo-fan        2750
# Turbo-jet         535
# Turbo-prop          2
# Turbo-shaft         5
# dtype: int64

# %%
result = planes.groupby("engine").size().reset_index()
result.columns = ["engine","COUNT(*)"]
result = result[["COUNT(*)", "engine"]]
result
# Out:
#    COUNT(*)         engine
# 0         2        4 Cycle
# 1        28  Reciprocating
# 2      2750      Turbo-fan
# 3       535      Turbo-jet
# 4         2     Turbo-prop
# 5         5    Turbo-shaft

# %% [markdown]
# ## 4

# %%
sql_result = pd.read_sql_query("SELECT COUNT(*), engine, type FROM planes GROUP BY engine, type", con)
sql_result
# Out:
#    COUNT(*)         engine                      type
# 0         2        4 Cycle  Fixed wing single engine
# 1         5  Reciprocating   Fixed wing multi engine
# 2        23  Reciprocating  Fixed wing single engine
# 3      2750      Turbo-fan   Fixed wing multi engine
# 4       535      Turbo-jet   Fixed wing multi engine
# 5         2     Turbo-prop   Fixed wing multi engine
# 6         5    Turbo-shaft                Rotorcraft

# %%
result.columns = np.hstack([result.columns.values[:1], "asd", result.columns.values[1:]])
# Out:
# array(['engine', 'asd', 0], dtype=object)

# %%
result = planes.groupby(["engine","type"]).size().reset_index()
result.columns = np.hstack([result.columns.values[:2], "COUNT(*)", result.columns.values[3:]])
result
# Out:
#           engine                      type  COUNT(*)
# 0        4 Cycle  Fixed wing single engine         2
# 1  Reciprocating   Fixed wing multi engine         5
# 2  Reciprocating  Fixed wing single engine        23
# 3      Turbo-fan   Fixed wing multi engine      2750
# 4      Turbo-jet   Fixed wing multi engine       535
# 5     Turbo-prop   Fixed wing multi engine         2
# 6    Turbo-shaft                Rotorcraft         5

# %%
result = pd.crosstab(planes.engine, planes.type).stack() #stack szeroki => dlugi
result = result[result > 0]
result = result.reset_index()
result.columns = np.hstack([result.columns.values[:2], "COUNT(*)", result.columns.values[3:]])
result
# Out:
#           engine                      type  COUNT(*)
# 0        4 Cycle  Fixed wing single engine         2
# 1  Reciprocating   Fixed wing multi engine         5
# 2  Reciprocating  Fixed wing single engine        23
# 3      Turbo-fan   Fixed wing multi engine      2750
# 4      Turbo-jet   Fixed wing multi engine       535
# 5     Turbo-prop   Fixed wing multi engine         2
# 6    Turbo-shaft                Rotorcraft         5

# %%
pd.crosstab(planes.engine, planes.type).stack()
# Out:
# engine         type
# 4 Cycle        Fixed wing multi engine        0
#                Fixed wing single engine       2
#                Rotorcraft                     0
# Reciprocating  Fixed wing multi engine        5
#                Fixed wing single engine      23
#                Rotorcraft                     0
# Turbo-fan      Fixed wing multi engine     2750
#                Fixed wing single engine       0
#                Rotorcraft                     0
# Turbo-jet      Fixed wing multi engine      535
#                Fixed wing single engine       0
#                Rotorcraft                     0
# Turbo-prop     Fixed wing multi engine        2
#                Fixed wing single engine       0
#                Rotorcraft                     0
# Turbo-shaft    Fixed wing multi engine        0
#                Fixed wing single engine       0
#                Rotorcraft                     5
# dtype: int64

# %%
pd.crosstab(planes.engine, planes.type).unstack()
# Out:
# type                      engine
# Fixed wing multi engine   4 Cycle             0
#                           Reciprocating       5
#                           Turbo-fan        2750
#                           Turbo-jet         535
#                           Turbo-prop          2
#                           Turbo-shaft         0
# Fixed wing single engine  4 Cycle             2
#                           Reciprocating      23
#                           Turbo-fan           0
#                           Turbo-jet           0
#                           Turbo-prop          0
#                           Turbo-shaft         0
# Rotorcraft                4 Cycle             0
#                           Reciprocating       0
#                           Turbo-fan           0
#                           Turbo-jet           0
#                           Turbo-prop          0
#                           Turbo-shaft         5
# dtype: int64

# %% [markdown]
# ## 5

# %%
sql_result = pd.read_sql_query("SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer FROM planes GROUP BY engine, manufacturer", con)
sql_result
# Out:
#     MIN(year)    AVG(year)  MAX(year)         engine  \
# 0      1975.0  1975.000000     1975.0        4 Cycle
# 1         NaN          NaN        NaN        4 Cycle
# 2         NaN          NaN        NaN  Reciprocating
# 3      2007.0  2007.000000     2007.0  Reciprocating
# 4         NaN          NaN        NaN  Reciprocating
# 5      1959.0  1971.142857     1983.0  Reciprocating
# 6      2007.0  2007.000000     2007.0  Reciprocating
# 7      1959.0  1959.000000     1959.0  Reciprocating
# 8      1956.0  1956.000000     1956.0  Reciprocating
# 9      2007.0  2007.000000     2007.0  Reciprocating
# 10        NaN          NaN        NaN  Reciprocating
# 11     1985.0  1985.000000     1985.0  Reciprocating
# 12        NaN          NaN        NaN  Reciprocating
# 13     1985.0  1985.000000     1985.0  Reciprocating
# 14     1993.0  1993.000000     1993.0  Reciprocating
# 15        NaN          NaN        NaN  Reciprocating
# 16     1968.0  1976.400000     1980.0  Reciprocating
# ...

# %%
# result = planes.groupby(["engine","manufacturer"])["year"].agg(["min", "mean","max"])
result = planes[["engine","manufacturer","year"]].groupby(["engine","manufacturer"]).agg({"year" : ["min", "mean","max"]})
result.columns = ["MIN(year)", "AVG(year)", "MAX(year)"]
result = result.reset_index()
result
# Out:
#            engine                   manufacturer  MIN(year)    AVG(year)  \
# 0         4 Cycle                         CESSNA     1975.0  1975.000000
# 1         4 Cycle                    JOHN G HESS        NaN          NaN
# 2   Reciprocating          AMERICAN AIRCRAFT INC        NaN          NaN
# 3   Reciprocating             AVIAT AIRCRAFT INC     2007.0  2007.000000
# 4   Reciprocating                  BARKER JACK L        NaN          NaN
# 5   Reciprocating                         CESSNA     1959.0  1971.142857
# 6   Reciprocating             CIRRUS DESIGN CORP     2007.0  2007.000000
# 7   Reciprocating                    DEHAVILLAND     1959.0  1959.000000
# 8   Reciprocating                        DOUGLAS     1956.0  1956.000000
# 9   Reciprocating                 FRIEDEMANN JON     2007.0  2007.000000
# 10  Reciprocating             HURLEY JAMES LARRY        NaN          NaN
# 11  Reciprocating                   KILDALL GARY     1985.0  1985.000000
# ...

# %% [markdown]
# ## 6

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE speed IS NOT NULL", con)
sql_result
# Out:
#     index tailnum    year                      type       manufacturer  \
# 0     424  N201AA  1959.0  Fixed wing single engine             CESSNA
# 1     427  N202AA  1980.0   Fixed wing multi engine             CESSNA
# 2     821  N350AA  1980.0   Fixed wing multi engine              PIPER
# 3     893  N364AA  1973.0   Fixed wing multi engine             CESSNA
# 4    1027  N378AA  1963.0  Fixed wing single engine             CESSNA
# 5    1037  N381AA  1956.0   Fixed wing multi engine            DOUGLAS
# 6    1190  N425AA  1968.0  Fixed wing single engine              PIPER
# 7    1430  N508AA  1975.0                Rotorcraft               BELL
# 8    1480  N519MQ  1983.0  Fixed wing single engine             CESSNA
# 9    1515  N525AA  1980.0   Fixed wing multi engine              PIPER
# 10   1589  N545AA  1976.0  Fixed wing single engine              PIPER
# 11   1694  N567AA  1959.0  Fixed wing single engine        DEHAVILLAND
# ...

# %%
len(planes)
# Out:
# 3322

# %%
planes.shape
# Out:
# (3322, 9)

# %%
#dobrze
np.sum(pd.isnull(planes.speed))
# Out:
# 3299

# %%
#dobrze
np.sum(np.isnan(planes.speed))
# Out:
# 3299

# %%
#zle
np.sum(planes.speed != np.NaN)
# Out:
# 3322

# %%
np.NaN != np.NaN
# Out:
# True

# %%
np.NaN == np.NaN
# Out:
# False

# %%
planes[~pd.isnull(planes.speed)].reset_index(drop=True)
# Out:
#    tailnum    year                      type       manufacturer        model  \
# 0   N201AA  1959.0  Fixed wing single engine             CESSNA          150
# 1   N202AA  1980.0   Fixed wing multi engine             CESSNA         421C
# 2   N350AA  1980.0   Fixed wing multi engine              PIPER    PA-31-350
# 3   N364AA  1973.0   Fixed wing multi engine             CESSNA         310Q
# 4   N378AA  1963.0  Fixed wing single engine             CESSNA         172E
# 5   N381AA  1956.0   Fixed wing multi engine            DOUGLAS       DC-7BF
# 6   N425AA  1968.0  Fixed wing single engine              PIPER    PA-28-180
# 7   N508AA  1975.0                Rotorcraft               BELL         206B
# 8   N519MQ  1983.0  Fixed wing single engine             CESSNA        A185F
# 9   N525AA  1980.0   Fixed wing multi engine              PIPER    PA-31-350
# 10  N545AA  1976.0  Fixed wing single engine              PIPER   PA-32R-300
# ...

# %% [markdown]
# ## 7

# %%
sql_result = pd.read_sql_query("SELECT tailnum FROM planes WHERE year >= 2010", con)
sql_result
# Out:
#     tailnum
# 0    N127UW
# 1    N128UW
# 2    N150UW
# 3    N151UW
# 4    N152UW
# 5    N153UW
# 6    N154UW
# 7    N155UW
# 8    N156UW
# 9    N157UW
# 10   N198UW
# 11   N199UW
# 12   N205FR
# 13   N206FR
# 14   N207FR
# 15   N208FR
# 16   N20904
# 17   N209FR
# 18   N210FR
# 19   N211FR
# 20   N213FR
# 21   N214FR
# 22   N216FR
# 23   N26906
# 24   N272PQ
# 25   N27477
# 26   N27901
# 27   N279PQ
# 28   N28457
# 29   N28478
# ..      ...
# 271  N913JB
# 272  N943WN
# 273  N944WN
# 274  N945WN
# 275  N946WN
# 276  N947WN
# 277  N948WN
# 278  N949WN
# 279  N950WN
# 280  N951WN
# 281  N952FR
# 282  N952WN
# 283  N953FR
# 284  N953WN
# 285  N954WN
# 286  N955WN
# 287  N956WN
# 288  N957WN
# 289  N958WN
# 290  N959WN
# 291  N960WN
# 292  N961WN
# 293  N962WN
# 294  N963WN
# 295  N964WN
# 296  N965WN
# 297  N966WN
# 298  N967WN
# 299  N968WN
# 300  N969WN
#
# [301 rows x 1 columns]

# %%
pd.DataFrame(planes[planes.year>=2010]["tailnum"]).reset_index(drop=True)
# Out:
#     tailnum
# 0    N127UW
# 1    N128UW
# 2    N150UW
# 3    N151UW
# 4    N152UW
# 5    N153UW
# 6    N154UW
# 7    N155UW
# 8    N156UW
# 9    N157UW
# 10   N198UW
# 11   N199UW
# 12   N205FR
# 13   N206FR
# 14   N207FR
# 15   N208FR
# 16   N20904
# 17   N209FR
# 18   N210FR
# 19   N211FR
# 20   N213FR
# 21   N214FR
# 22   N216FR
# 23   N26906
# 24   N272PQ
# 25   N27477
# 26   N27901
# 27   N279PQ
# 28   N28457
# 29   N28478
# ..      ...
# 271  N913JB
# 272  N943WN
# 273  N944WN
# 274  N945WN
# 275  N946WN
# 276  N947WN
# 277  N948WN
# 278  N949WN
# 279  N950WN
# 280  N951WN
# 281  N952FR
# 282  N952WN
# 283  N953FR
# 284  N953WN
# 285  N954WN
# 286  N955WN
# 287  N956WN
# 288  N957WN
# 289  N958WN
# 290  N959WN
# 291  N960WN
# 292  N961WN
# 293  N962WN
# 294  N963WN
# 295  N964WN
# 296  N965WN
# 297  N966WN
# 298  N967WN
# 299  N968WN
# 300  N969WN
#
# [301 rows x 1 columns]

# %% [markdown]
# ## 8

# %%
sql_result = pd.read_sql_query("SELECT tailnum FROM planes WHERE seats BETWEEN 100 and 200 LIMIT 20", con)
sql_result
# Out:
#    tailnum
# 0   N102UW
# 1   N103US
# 2   N104UW
# 3   N105UW
# 4   N107US
# 5   N108UW
# 6   N109UW
# 7   N110UW
# 8   N111US
# 9   N11206
# 10  N112US
# 11  N113UW
# 12  N114UW
# 13  N117UW
# 14  N118US
# 15  N119US
# 16  N12109
# 17  N12114
# 18  N12116
# 19  N12125

# %%
pd.DataFrame(planes["tailnum"][(planes.seats >= 100) & (planes.seats <= 200)]\
             .head(20)).reset_index(drop=True)
# Out:
#    tailnum
# 0   N102UW
# 1   N103US
# 2   N104UW
# 3   N105UW
# 4   N107US
# 5   N108UW
# 6   N109UW
# 7   N110UW
# 8   N111US
# 9   N11206
# 10  N112US
# 11  N113UW
# 12  N114UW
# 13  N117UW
# 14  N118US
# 15  N119US
# 16  N12109
# 17  N12114
# 18  N12116
# 19  N12125

# %% [markdown]
# ## 9

# %%
sql_result = pd.read_sql_query('SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER")', con)
sql_result
# Out:
#       index tailnum    year                     type manufacturer      model  \
# 0         0  N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 1         4  N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR
# 2        10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 3        11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 4        12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 5        13  N11113  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 6        14  N11119  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 7        15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 8        16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 9        17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 10       18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# ...

# %%
planes[planes.manufacturer.isin(["BOEING", "AIRBUS", "EMBRAER"])].reset_index(drop=False)
# Out:
#       index tailnum    year                     type manufacturer      model  \
# 0         0  N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 1         4  N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR
# 2        10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 3        11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 4        12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 5        13  N11113  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 6        14  N11119  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 7        15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 8        16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 9        17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 10       18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# ...

# %% [markdown]
# ## 10

# %%
sql_result = pd.read_sql_query('SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats > 300', con)
sql_result
# Out:
#      index tailnum    year                     type manufacturer     model  \
# 0       49  N1200K  1998.0  Fixed wing multi engine       BOEING   767-332
# 1       50  N1201P  1998.0  Fixed wing multi engine       BOEING   767-332
# 2       69  N121DE  1987.0  Fixed wing multi engine       BOEING   767-332
# 3      117  N136DL  1991.0  Fixed wing multi engine       BOEING   767-332
# 4      122  N137DL  1991.0  Fixed wing multi engine       BOEING   767-332
# 5      183  N143DA  1998.0  Fixed wing multi engine       BOEING   767-332
# 6      241   N1602  1999.0  Fixed wing multi engine       BOEING   767-332
# 7      242   N1603  1999.0  Fixed wing multi engine       BOEING   767-332
# 8      243  N1604R  1999.0  Fixed wing multi engine       BOEING   767-332
# 9      244   N1605  1999.0  Fixed wing multi engine       BOEING   767-332
# 10     245  N16065  1999.0  Fixed wing multi engine       BOEING   767-332
# ...

# %%
planes[planes.manufacturer.isin(["BOEING", "AIRBUS", "EMBRAER"]) & (planes.seats>300)]\
       .reset_index(drop=False)
# Out:
#      index tailnum    year                     type manufacturer     model  \
# 0       49  N1200K  1998.0  Fixed wing multi engine       BOEING   767-332
# 1       50  N1201P  1998.0  Fixed wing multi engine       BOEING   767-332
# 2       69  N121DE  1987.0  Fixed wing multi engine       BOEING   767-332
# 3      117  N136DL  1991.0  Fixed wing multi engine       BOEING   767-332
# 4      122  N137DL  1991.0  Fixed wing multi engine       BOEING   767-332
# 5      183  N143DA  1998.0  Fixed wing multi engine       BOEING   767-332
# 6      241   N1602  1999.0  Fixed wing multi engine       BOEING   767-332
# 7      242   N1603  1999.0  Fixed wing multi engine       BOEING   767-332
# 8      243  N1604R  1999.0  Fixed wing multi engine       BOEING   767-332
# 9      244   N1605  1999.0  Fixed wing multi engine       BOEING   767-332
# 10     245  N16065  1999.0  Fixed wing multi engine       BOEING   767-332
# ...

# %% [markdown]
# ## 11

# %%
sql_result = pd.read_sql_query('SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer', con)
sql_result
# Out:
#        manufacturer  COUNT(*)
# 0            AIRBUS        66
# 1  AIRBUS INDUSTRIE         4
# 2            BOEING       225

# %%
planes["manufacturer"][planes.seats>200].value_counts().reset_index()
# Out:
#               index  manufacturer
# 0            BOEING           225
# 1            AIRBUS            66
# 2  AIRBUS INDUSTRIE             4

# %%
planes[planes.seats>200].groupby("manufacturer").size().reset_index()
# Out:
#        manufacturer    0
# 0            AIRBUS   66
# 1  AIRBUS INDUSTRIE    4
# 2            BOEING  225

# %% [markdown]
# ## 12

# %%
sql_result = pd.read_sql_query('SELECT manufacturer, COUNT(*) FROM planes GROUP BY manufacturer HAVING COUNT(*) > 10', con)
sql_result
# Out:
#                     manufacturer  COUNT(*)
# 0                         AIRBUS       336
# 1               AIRBUS INDUSTRIE       400
# 2                         BOEING      1630
# 3                 BOMBARDIER INC       368
# 4                        EMBRAER       299
# 5              MCDONNELL DOUGLAS       120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO       103
# 7  MCDONNELL DOUGLAS CORPORATION        14

# %%
wynik = planes.groupby("manufacturer").size()
wynik[wynik > 10].reset_index()
# Out:
#                     manufacturer     0
# 0                         AIRBUS   336
# 1               AIRBUS INDUSTRIE   400
# 2                         BOEING  1630
# 3                 BOMBARDIER INC   368
# 4                        EMBRAER   299
# 5              MCDONNELL DOUGLAS   120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO   103
# 7  MCDONNELL DOUGLAS CORPORATION    14

# %% [markdown]
# ## 13

# %%
sql_result = pd.read_sql_query('SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer HAVING COUNT(*) > 10', con)
sql_result
# Out:
#   manufacturer  COUNT(*)
# 0       AIRBUS        66
# 1       BOEING       225

# %%
wynik = planes[planes.seats > 200].groupby("manufacturer").size()
wynik[wynik > 10].reset_index()
# Out:
#   manufacturer    0
# 0       AIRBUS   66
# 1       BOEING  225

# %% [markdown]
# ## 14

# %%
sql_result = pd.read_sql_query\
    ('SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany', con)
sql_result
# Out:
#                      manufacturer  howmany
# 0                      AGUSTA SPA        1
# 1              AVIAT AIRCRAFT INC        1
# 2          AVIONS MARCEL DASSAULT        1
# 3                   BARKER JACK L        1
# 4                    CANADAIR LTD        1
# 5              CIRRUS DESIGN CORP        1
# 6                     DEHAVILLAND        1
# 7                         DOUGLAS        1
# 8                  FRIEDEMANN JON        1
# 9              HURLEY JAMES LARRY        1
# 10                    JOHN G HESS        1
# 11                   KILDALL GARY        1
# 12                LAMBERT RICHARD        1
# 13                    LEARJET INC        1
# 14                LEBLANC GLENN T        1
# 15                     MARZ BARRY        1
# 16                    PAIR MIKE E        1
# 17         ROBINSON HELICOPTER CO        1
# 18                       SIKORSKY        1
# 19          AMERICAN AIRCRAFT INC        2
# 20                          BEECH        2
# ...

# %%
planes.manufacturer.value_counts(ascending=True).reset_index()
# Out:
#                             index  manufacturer
# 0                         DOUGLAS             1
# 1                     LEARJET INC             1
# 2                        SIKORSKY             1
# 3                     PAIR MIKE E             1
# 4                     JOHN G HESS             1
# 5                 LAMBERT RICHARD             1
# 6                     DEHAVILLAND             1
# 7                  FRIEDEMANN JON             1
# 8          AVIONS MARCEL DASSAULT             1
# 9                    KILDALL GARY             1
# 10                   CANADAIR LTD             1
# 11                  BARKER JACK L             1
# 12             HURLEY JAMES LARRY             1
# 13                LEBLANC GLENN T             1
# 14             AVIAT AIRCRAFT INC             1
# 15             CIRRUS DESIGN CORP             1
# 16         ROBINSON HELICOPTER CO             1
# 17                     AGUSTA SPA             1
# 18                     MARZ BARRY             1
# ...

# %%
planes.groupby("manufacturer").size().sort_values().reset_index()
# Out:
#                      manufacturer     0
# 0                      AGUSTA SPA     1
# 1                         DOUGLAS     1
# 2                     DEHAVILLAND     1
# 3              CIRRUS DESIGN CORP     1
# 4              HURLEY JAMES LARRY     1
# 5                    CANADAIR LTD     1
# 6                     JOHN G HESS     1
# 7                    KILDALL GARY     1
# 8                        SIKORSKY     1
# 9                 LAMBERT RICHARD     1
# 10                LEBLANC GLENN T     1
# 11                  BARKER JACK L     1
# 12         AVIONS MARCEL DASSAULT     1
# 13             AVIAT AIRCRAFT INC     1
# 14                     MARZ BARRY     1
# 15                    PAIR MIKE E     1
# 16         ROBINSON HELICOPTER CO     1
# 17                    LEARJET INC     1
# 18                 FRIEDEMANN JON     1
# 19                   STEWART MACO     2
# 20                           BELL     2
# 21                          BEECH     2
# ...

# %%
planes.manufacturer.value_counts(ascending=True).reset_index().equals(planes.groupby("manufacturer").size().sort_values().reset_index())
# Out:
# False

# %% [markdown]
# ## 15

# %%
sql_result = pd.read_sql_query\
    ('SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany DESC LIMIT 10', con)
sql_result
# Out:
#                     manufacturer  howmany
# 0                         BOEING     1630
# 1               AIRBUS INDUSTRIE      400
# 2                 BOMBARDIER INC      368
# 3                         AIRBUS      336
# 4                        EMBRAER      299
# 5              MCDONNELL DOUGLAS      120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO      103
# 7  MCDONNELL DOUGLAS CORPORATION       14
# 8                       CANADAIR        9
# 9                         CESSNA        9

# %%
planes.manufacturer.value_counts(ascending=False).reset_index().head(10)
# Out:
#                            index  manufacturer
# 0                         BOEING          1630
# 1               AIRBUS INDUSTRIE           400
# 2                 BOMBARDIER INC           368
# 3                         AIRBUS           336
# 4                        EMBRAER           299
# 5              MCDONNELL DOUGLAS           120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO           103
# 7  MCDONNELL DOUGLAS CORPORATION            14
# 8                       CANADAIR             9
# 9                         CESSNA             9

# %%
planes.groupby("manufacturer").size().sort_values(ascending=False).reset_index().head(10)
# Out:
#                     manufacturer     0
# 0                         BOEING  1630
# 1               AIRBUS INDUSTRIE   400
# 2                 BOMBARDIER INC   368
# 3                         AIRBUS   336
# 4                        EMBRAER   299
# 5              MCDONNELL DOUGLAS   120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO   103
# 7  MCDONNELL DOUGLAS CORPORATION    14
# 8                       CANADAIR     9
# 9                         CESSNA     9

# %% [markdown]
# ## 16

# %%
sql_result = pd.read_sql_query\
    ('SELECT * FROM planes WHERE year >= 2012 ORDER BY year, seats', con)
sql_result
# Out:
#      index tailnum    year                     type            manufacturer  \
# 0     1564  N537JB  2012.0               Rotorcraft  ROBINSON HELICOPTER CO
# 1      815  N348JB  2012.0  Fixed wing multi engine                 EMBRAER
# 2      825  N351JB  2012.0  Fixed wing multi engine                 EMBRAER
# 3      837  N353JB  2012.0  Fixed wing multi engine                 EMBRAER
# 4     2630  N8301J  2012.0  Fixed wing multi engine                  BOEING
# 5     2631  N8302F  2012.0  Fixed wing multi engine                  BOEING
# 6     2633  N8305E  2012.0  Fixed wing multi engine                  BOEING
# 7     2634  N8306H  2012.0  Fixed wing multi engine                  BOEING
# 8     2635  N8307K  2012.0  Fixed wing multi engine                  BOEING
# 9     2636  N8308K  2012.0  Fixed wing multi engine                  BOEING
# 10    2637  N8309C  2012.0  Fixed wing multi engine                  BOEING
# ...

# %%
planes[planes.year>=2012].sort_values(by=["year","seats"]).reset_index()#.equals(sql_result)
# Out:
#      index tailnum    year                     type            manufacturer  \
# 0     1564  N537JB  2012.0               Rotorcraft  ROBINSON HELICOPTER CO
# 1      815  N348JB  2012.0  Fixed wing multi engine                 EMBRAER
# 2      825  N351JB  2012.0  Fixed wing multi engine                 EMBRAER
# 3      837  N353JB  2012.0  Fixed wing multi engine                 EMBRAER
# 4     2630  N8301J  2012.0  Fixed wing multi engine                  BOEING
# 5     2631  N8302F  2012.0  Fixed wing multi engine                  BOEING
# 6     2633  N8305E  2012.0  Fixed wing multi engine                  BOEING
# 7     2634  N8306H  2012.0  Fixed wing multi engine                  BOEING
# 8     2635  N8307K  2012.0  Fixed wing multi engine                  BOEING
# 9     2636  N8308K  2012.0  Fixed wing multi engine                  BOEING
# 10    2637  N8309C  2012.0  Fixed wing multi engine                  BOEING
# ...

# %% [markdown]
# ## 17

# %%
planes[planes.year>=2012].sort_values(by=["seats","year"])
# Out:
#      tailnum    year                     type            manufacturer  \
# 1564  N537JB  2012.0               Rotorcraft  ROBINSON HELICOPTER CO
# 815   N348JB  2012.0  Fixed wing multi engine                 EMBRAER
# 825   N351JB  2012.0  Fixed wing multi engine                 EMBRAER
# 837   N353JB  2012.0  Fixed wing multi engine                 EMBRAER
# 843   N354JB  2013.0  Fixed wing multi engine                 EMBRAER
# 848   N355JB  2013.0  Fixed wing multi engine                 EMBRAER
# 859   N358JB  2013.0  Fixed wing multi engine                 EMBRAER
# 908   N368JB  2013.0  Fixed wing multi engine                 EMBRAER
# 956   N373JB  2013.0  Fixed wing multi engine                 EMBRAER
# 989   N374JB  2013.0  Fixed wing multi engine                 EMBRAER
# 1003  N375JB  2013.0  Fixed wing multi engine                 EMBRAER
# 578   N272PQ  2013.0  Fixed wing multi engine          BOMBARDIER INC
# ...

# %% [markdown]
# ## Wybierz 100 losowych wierszy z airports

# %%
airports.sample(n=100)
# Out:
#       faa                                  name        lat         lon   alt  \
# 1165  RNO                       Reno Tahoe Intl  39.499108 -119.768108  4415
# 559   GRR                    Gerald R Ford Intl  42.880833  -85.522806   794
# 1378  VLD             Valdosta Regional Airport  30.782500  -83.276700   203
# 694   JHW           Chautauqua County-Jamestown  42.153333  -79.258056   525
# 1243  SMD                             Smith Fld  41.143353  -85.152778   834
# 1100  PPV         Port Protection Seaplane Base  56.328889 -133.610000     0
# 217   BMG                 Monroe County Airport  39.146021  -86.616681   846
# 320   COT                    Cotulla Lasalle Co  28.456694  -99.220294   474
# 693   JHM                               Kapalua  20.962936 -156.673031   256
# 197   BIL  Billings Logan International Airport  45.809210 -108.537654  3652
# 1398  WFK   Northern Aroostook Regional Airport  47.285556  -68.312778   988
# ...

# %% [markdown]
# ## Wybierz 5% losowych wierszy z airports

# %%
airports.sample(frac=0.05)
# Out:
#       faa                                       name        lat         lon  \
# 818   LSF                                 Lawson Aaf  32.337322  -84.991283
# 175   BDE                              Baudette Intl  48.728444  -94.612222
# 188   BFT                                   Beaufort  32.477411  -80.723161
# 1039  OWB           Owensboro Daviess County Airport  37.740100  -87.166800
# 58    55J         Fernandina Beach Municipal Airport  30.611833  -81.461194
# 1104  PRL                       Port Oceanic Airport  60.208333 -147.819444
# 202   BJI                   Bemidji Regional Airport  47.510722  -94.934722
# 1168  ROC                     Greater Rochester Intl  43.118866  -77.672389
# 1367  VAK                             Chevak Airport  61.533800 -165.584000
# 6     0G6                    Williams County Airport  41.467306  -84.506778
# 1448  ZRZ                New Carrollton Rail Station  38.948000  -76.871900
# ...

# %% [markdown]
# ## Wybierz 100 pierwszych wierszy

# %%
airports.head(100)
# Out:
#     faa                                  name        lat         lon   alt  \
# 0   04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1   06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2   06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3   06N                       Randall Airport  41.431912  -74.391561   523
# 4   09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5   0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6   0G6               Williams County Airport  41.467306  -84.506778   730
# 7   0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8   0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9   0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10  0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# ## Wybierz 100 ostatnich wierszy

# %%
airports.tail(100)
# Out:
#       faa                                  name        lat         lon   alt  \
# 1358  UPP                                 Upolu  20.265256 -155.859989    96
# 1359  UST                 St. Augustine Airport  29.959167  -81.339722    10
# 1360  UT3                          Hite Airport  37.891655 -110.384029  3840
# 1361  UTM              Tunica Municipal Airport  34.681000  -90.346700   194
# 1362  UTO                  Indian Mountain Lrrs  65.992794 -153.704289  1220
# 1363  UUK                  Ugnu-Kuparuk Airport  70.330833 -149.597500    67
# 1364  UUU                         Newport State  41.533056  -71.282222   172
# 1365  UVA                          Garner Field  29.215429  -99.748962   942
# 1366  VAD                             Moody Afb  30.967833  -83.193000   233
# 1367  VAK                        Chevak Airport  61.533800 -165.584000    75
# 1368  VAY         South Jersey Regional Airport  39.942889  -74.845750    53
# ...

# %% [markdown]
# ## Union, intersect, except

# %%
A = airports.iloc[0:11]
B = airports.iloc[5:16]

# %% [markdown]
# ### SELECT * FROM A UNION ALL SELECT * FROM B

# %%
pd.concat([A,B])
# Out:
#     faa                                  name        lat         lon   alt  \
# 0   04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1   06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2   06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3   06N                       Randall Airport  41.431912  -74.391561   523
# 4   09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5   0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6   0G6               Williams County Airport  41.467306  -84.506778   730
# 7   0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8   0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9   0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10  0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %%
A.append(B)
# Out:
#     faa                                  name        lat         lon   alt  \
# 0   04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1   06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2   06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3   06N                       Randall Airport  41.431912  -74.391561   523
# 4   09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5   0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6   0G6               Williams County Airport  41.467306  -84.506778   730
# 7   0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8   0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9   0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10  0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# ### SELECT * FROM A UNION SELECT * FROM B

# %%
pd.concat([A,B]).drop_duplicates()
# Out:
#     faa                                  name        lat         lon   alt  \
# 0   04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1   06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2   06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3   06N                       Randall Airport  41.431912  -74.391561   523
# 4   09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5   0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6   0G6               Williams County Airport  41.467306  -84.506778   730
# 7   0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8   0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9   0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10  0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %% [markdown]
# ## SELECT * FROM A INTERSECT SELECT * FROM B

# %%
pd.merge(A,B)
# Out:
#    faa                            name        lat         lon   alt  tz dst  \
# 0  0A9  Elizabethton Municipal Airport  36.371222  -82.173417  1593  -5   A
# 1  0G6         Williams County Airport  41.467306  -84.506778   730  -5   A
# 2  0G7   Finger Lakes Regional Airport  42.883565  -76.781232   492  -5   A
# 3  0P2    Shoestring Aviation Airfield  39.794824  -76.647191  1000  -5   U
# 4  0S9           Jefferson County Intl  48.053809 -122.810644   108  -8   A
# 5  0W3          Harford County Airport  39.566838  -76.202403   409  -5   A
#
#                  tzone
# 0     America/New_York
# 1     America/New_York
# 2     America/New_York
# 3     America/New_York
# 4  America/Los_Angeles
# 5     America/New_York

# %%
A[A.lat.isin(B.lat)].reset_index(drop=True)
# Out:
#    faa                            name        lat         lon   alt  tz dst  \
# 0  0A9  Elizabethton Municipal Airport  36.371222  -82.173417  1593  -5   A
# 1  0G6         Williams County Airport  41.467306  -84.506778   730  -5   A
# 2  0G7   Finger Lakes Regional Airport  42.883565  -76.781232   492  -5   A
# 3  0P2    Shoestring Aviation Airfield  39.794824  -76.647191  1000  -5   U
# 4  0S9           Jefferson County Intl  48.053809 -122.810644   108  -8   A
# 5  0W3          Harford County Airport  39.566838  -76.202403   409  -5   A
#
#                  tzone
# 0     America/New_York
# 1     America/New_York
# 2     America/New_York
# 3     America/New_York
# 4  America/Los_Angeles
# 5     America/New_York

# %%
B[B.isin(A)].dropna()
# Out:
#     faa                            name        lat         lon     alt   tz  \
# 5   0A9  Elizabethton Municipal Airport  36.371222  -82.173417  1593.0 -5.0
# 6   0G6         Williams County Airport  41.467306  -84.506778   730.0 -5.0
# 7   0G7   Finger Lakes Regional Airport  42.883565  -76.781232   492.0 -5.0
# 8   0P2    Shoestring Aviation Airfield  39.794824  -76.647191  1000.0 -5.0
# 9   0S9           Jefferson County Intl  48.053809 -122.810644   108.0 -8.0
# 10  0W3          Harford County Airport  39.566838  -76.202403   409.0 -5.0
#
#    dst                tzone
# 5    A     America/New_York
# 6    A     America/New_York
# 7    A     America/New_York
# 8    U     America/New_York
# 9    A  America/Los_Angeles
# 10   A     America/New_York

# %%
B.isin(A)
# Out:
#       faa   name    lat    lon    alt     tz    dst  tzone
# 5    True   True   True   True   True   True   True   True
# 6    True   True   True   True   True   True   True   True
# 7    True   True   True   True   True   True   True   True
# 8    True   True   True   True   True   True   True   True
# 9    True   True   True   True   True   True   True   True
# 10   True   True   True   True   True   True   True   True
# 11  False  False  False  False  False  False  False  False
# 12  False  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False  False
# 15  False  False  False  False  False  False  False  False

# %% [markdown]
# ## SELECT * FROM A EXCEPT SELECT * FROM B

# %%
A[~A.isin(B)].dropna()
# Out:
#    faa                           name        lat        lon     alt   tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044.0 -5.0   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264.0 -6.0   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801.0 -6.0   A
# 3  06N                Randall Airport  41.431912 -74.391561   523.0 -5.0   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11.0 -5.0   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %% [markdown]
# ## SELECT * FROM B EXCEPT SELECT * FROM A

# %%
~B.isin(A)
# Out:
#       faa   name    lat    lon    alt     tz    dst  tzone
# 5   False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False
# 11   True   True   True   True   True   True   True   True
# 12   True   True   True   True   True   True   True   True
# 13   True   True   True   True   True   True   True   True
# 14   True   True   True   True   True   True   True   True
# 15   True   True   True   True   True   True   True   True

# %%
B
# Out:
#     faa                                  name        lat         lon   alt  \
# 5   0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6   0G6               Williams County Airport  41.467306  -84.506778   730
# 7   0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8   0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9   0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10  0W3                Harford County Airport  39.566838  -76.202403   409
# 11  10C                    Galt Field Airport  42.402889  -88.375111   875
# 12  17G  Port Bucyrus-Crawford County Airport  40.781556  -82.974806  1003
# 13  19A                Jackson County Airport  34.175864  -83.561597   951
# 14  1A3         Martin Campbell Field Airport  35.015806  -84.346833  1789
# 15  1B9                   Mansfield Municipal  42.000133  -71.196771   122
#
#     tz dst                tzone
# 5   -5   A     America/New_York
# ...

# %%
B[~B.isin(A)]
# Out:
#     faa                                  name        lat        lon     alt  \
# 5   NaN                                   NaN        NaN        NaN     NaN
# 6   NaN                                   NaN        NaN        NaN     NaN
# 7   NaN                                   NaN        NaN        NaN     NaN
# 8   NaN                                   NaN        NaN        NaN     NaN
# 9   NaN                                   NaN        NaN        NaN     NaN
# 10  NaN                                   NaN        NaN        NaN     NaN
# 11  10C                    Galt Field Airport  42.402889 -88.375111   875.0
# 12  17G  Port Bucyrus-Crawford County Airport  40.781556 -82.974806  1003.0
# 13  19A                Jackson County Airport  34.175864 -83.561597   951.0
# 14  1A3         Martin Campbell Field Airport  35.015806 -84.346833  1789.0
# 15  1B9                   Mansfield Municipal  42.000133 -71.196771   122.0
#
#      tz  dst             tzone
# ...
