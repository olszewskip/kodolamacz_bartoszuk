# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel("file_example_XLSX_10.xlsx")
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
pd.read_excel("WypadkiwgwojewodztwIX2016.xls", skiprows=[0,1], skipfooter=1, sheet_name="ogółem")
# Out:
#     Unnamed: 0                                         Unnamed: 1  ciężki  \
# 0            1                                        Przedszkole      10
# 1            3                                  Szkoła podstawowa      62
# 2            4                                          Gimnazjum      53
# 3           13                         Zasadnicza szkoła zawodowa       0
# 4           14                            Liceum ogólnokształcące      13
# 5           16                                          Technikum       6
# 6           19               Szkoła policealna (ponadgimnazjalna)       0
# 7           20  Szkoła specjalna przysposabiająca do pracy dla...       1
# 8           21  Sześcioletnia ogólnokształcąca szkoła muzyczna...       0
# 9           22            Sześcioletnia szkoła muzyczna I stopnia       0
# 10          23             Czteroletnia szkoła muzyczna I stopnia       0
# 11          24  Sześcioletnia ogólnokształcąca szkoła muzyczna...       0
# ...

# %%
wojewodztwa = pd.read_excel("WypadkiwgwojewodztwIX2016.xls",\
                            sheet_name=1, skiprows=2, usecols=[1,3,4,5,6], index_col=[1,0],
                           skipfooter=1)
#swaplevels
wojewodztwa.sort_index(axis=0,level=0,inplace=True)
wojewodztwa
# Out:
#                                                                        ciężki  \
#                                              Unnamed: 0
# Bednarska Szkoła Realna                      WOJ. MAZOWIECKIE               0
# Bursa                                        WOJ. DOLNOŚLĄSKIE              0
#                                              WOJ. KUJAWSKO-POMORSKIE        0
#                                              WOJ. LUBELSKIE                 0
#                                              WOJ. MAŁOPOLSKIE               0
#                                              WOJ. PODLASKIE                 0
#                                              WOJ. POMORSKIE                 0
#                                              WOJ. WARMIŃSKO-MAZURSKIE       0
#                                              WOJ. WIELKOPOLSKIE             0
#                                              WOJ. ZACHODNIOPOMORSKIE        0
# ...

# %%
wojewodztwa.swaplevel()
# Out:
#                                                                             ciężki  \
# Unnamed: 1
# Przedszkole                                        WOJ. DOLNOŚLĄSKIE             0
# Szkoła podstawowa                                  WOJ. DOLNOŚLĄSKIE             8
# Gimnazjum                                          WOJ. DOLNOŚLĄSKIE             5
# Zasadnicza szkoła zawodowa                         WOJ. DOLNOŚLĄSKIE             0
# Liceum ogólnokształcące                            WOJ. DOLNOŚLĄSKIE             1
# Technikum                                          WOJ. DOLNOŚLĄSKIE             3
# Szkoła policealna (ponadgimnazjalna)               WOJ. DOLNOŚLĄSKIE             0
# Szkoła specjalna przysposabiająca do pracy dla ... WOJ. DOLNOŚLĄSKIE             0
# Sześcioletnia ogólnokształcąca szkoła muzyczna ... WOJ. DOLNOŚLĄSKIE             0
# Młodzieżowy dom kultury                            WOJ. DOLNOŚLĄSKIE             0
# ...
