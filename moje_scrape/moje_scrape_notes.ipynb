# %%
import io, os.path, re
import requests, urllib
import numpy as np
import pandas as pd
import re

# %%
f = requests.get("https://pl.wikipedia.org/wiki/Zygmunt_III_Waza")
f.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="pl" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Zygmunt III Waza – Wikipedia, wolna encyklopedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Zygmunt_III_Waza","wgTitle":"Zygmunt III Waza","wgCurRevisionId":53897110,"wgRevisionId":53897110,"wgArticleId":31966,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Biografie kanonu polskiej Wikipedii","Zygmunt III Waza","Władcy Polski","Władcy elekcyjni I Rzeczypospolitej","Władcy Litwy","Władcy Szwecji","Polscy działacze kontrreformacji","Polacy odznaczeni Orderem Złotego Runa","Uczestnicy wojny polsko-rosyjskiej 1609–1618 (strona polska)","Uczestnic
# ...

# %%
list_of_tup = re.findall(r"<a.*? href=\"(.*?)\".*?>(.*?)</a>", f.text)

# %%
pd.DataFrame(list_of_tup, columns=['href', 'opis'])
# Out:
#                                                   href  \
# 0                                             #mw-head
# 1                                            #p-search
# 2                  /wiki/Plik:Zygmunt_Waza_Soutman.jpg
# 3    /wiki/Plik:Coat_of_arms_of_Vasa_kings_of_Polan...
# 4       /wiki/Plik:Sigismundus_III_Rex_-_signature.png
# 5                               /wiki/Kr%C3%B3l_Polski
# 6                                    /wiki/Krak%C3%B3w
# 7                                  /wiki/Stefan_Batory
# 8                    /wiki/W%C5%82adys%C5%82aw_IV_Waza
# 9                            /wiki/W%C5%82adcy_Szwecji
# 10                                       /wiki/Uppsala
# 11                                  /wiki/Jan_III_Waza
# 12                                 /wiki/Karol_IX_Waza
# 13                          /wiki/Unia_polsko-szwedzka
# 14                                       /wiki/Wazowie
# 15                                    /wiki/20_czerwca
# ...

# %%
f = requests.get("https://stooq.pl/q/?s=cdr")
f.text
# Out:
# '<html><head><meta http-equiv=content-type content=text/html;charset=utf-8><meta name=keywords content="cdprojekt, cdr, wykresy, wykres, dane, notowania, gieÅ\x82da, rynek"><meta name=description content="Wykresy notowaÅ\x84 spÃ³Å\x82ek, indeksÃ³w, kontraktÃ³w, walut, obligacji i towarÃ³w."><title>CDR (+3.90%) - CD Projekt SA - Stooq</title><script>function cpr(a,b){var c=0, f=document.f_c, n=8, s=\'\';if(a){if(a.checked==true){if(b==\'wig20\'){f.r1.checked=true}else{f.r.value+=(f.r.value?\' \':\'\')+b.toUpperCase()}}else{if(b==\'wig20\'){f.r1.checked=false}else{b=b.replace(\'^\',\'\\\\^\');f.r.value=(\' \'+f.r.value+\' \').replace(new RegExp(\' \'+b+\' \',\'i\'),\' \');f.r.value=f.r.value.substring(1,f.r.value.length-1)}}}if(f.r.value){t=f.r.value.split(\' \');for(i=0;i<t.length;i++){ if(t[i].match(\'^[A-Za-z0-9._^]{2,16}$\') && (!f.r1.checked || t[i]!=\'wig20\')){ if(c++>=n) break; s+=t[i]+\'+\'; }}s=s.substring(0,s.length-1).toLowerCase();}if(f.r1.checked) s+=(s ? \'+\' : \'\')+f.
# ...

# %%
re.findall(
    r"Kurs<br>.*?<span.*?>(.*?)</span>",
    f.text
)
# Out:
# ['192.00']

# %%
pola=["Kurs", "Zmiana", "Zmiana 1r", "Data", "Otwarcie", "Wolumen"]
for pole in pola:
    found = re.findall(
            fr"{pole}<br>.*?<span.*?>(.*?)</span>",
            f.text
        )
    print(found)
# Out:
# ['192.00']
# ['+7.20']
# ['+108.60']
# ['2018-07-13']
# ['183.00']
# ['347k']

# %%
from bs4 import BeautifulSoup
import io, os.path, re
import requests, urllib, json
import numpy as np
import pandas as pd
import re

# %%
f = requests.get("https://pl.wikipedia.org/wiki/Zygmunt_III_Waza")
soup = BeautifulSoup(f.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Zygmunt III Waza – Wikipedia, wolna encyklopedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
soup("a")
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Przejdź do nawigacji</a>,
#  <a class="mw-jump-link" href="#p-search">Przejdź do wyszukiwania</a>,
#  <a class="image" href="/wiki/Plik:Zygmunt_Waza_Soutman.jpg"><img alt="ilustracja" data-file-height="1067" data-file-width="737" height="240" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/166px-Zygmunt_Waza_Soutman.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/249px-Zygmunt_Waza_Soutman.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/331px-Zygmunt_Waza_Soutman.jpg 2x" width="166"/></a>,
# ...

# %%
for link in soup.find_all('a',href=True):
    print("> ", link.get("href"))
    print(link.string)
    print(link.next_element, "\n")
# Out:
# >  #mw-head
# Przejdź do nawigacji
# Przejdź do nawigacji
#
# >  #p-search
# Przejdź do wyszukiwania
# Przejdź do wyszukiwania
#
# >  /wiki/Plik:Zygmunt_Waza_Soutman.jpg
# None
# <img alt="ilustracja" data-file-height="1067" data-file-width="737" height="240" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/166px-Zygmunt_Waza_Soutman.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/249px-Zygmunt_Waza_Soutman.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/50/Zygmunt_Waza_Soutman.jpg/331px-Zygmunt_Waza_Soutman.jpg 2x" width="166"/>
#
# >  /wiki/Plik:Coat_of_arms_of_Vasa_kings_of_Poland.svg
# None
# ...

# %%
# dane: https://www.filmweb.pl/film/Pi%C4%99%C4%87dziesi%C4%85t+twarzy+Greya-2015-655761
# szukane: reżyser, boxoffice, ocena

# %%
link = "https://www.filmweb.pl/film/Pi%C4%99%C4%87dziesi%C4%85t+twarzy+Greya-2015-655761"
f = requests.get(link)
soup = BeautifulSoup(f.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="www" lang="pl">
#  <head>
#   <script>
#    if(document.cookie.indexOf("showErrors")>-1){console.time("untilFwScreeningConstructor");console.time("untilFooter");console.time("runWhenReady");console.time("waitForIframe");console.time("dontWaitForIframe")};
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Pięćdziesiąt twarzy Greya (2015) - Filmweb
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="pl" http-equiv="content-language"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link color="#ECB014" href="https://2.fwcdn.pl/gf/beta/filmweb-touchbar-icon.svg" rel="mask-icon"/>
#   <link href="https://2.fwcdn.pl/gf/beta/ic/32x32-fw.png" rel="apple-touch-icon" sizes="32x32"/>
#   <link href="https://2.fwcdn.pl/gf/beta/ic60x60-fw.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://2.fwcdn.pl/gf/beta/ic/75x75-fw.png" rel="apple-touch-icon" sizes="75x75"/>
# ...

# %%
summary = soup.find(class_ = "filmInfo bottom-15")
print(summary.prettify())
# Out:
# <div class="filmInfo bottom-15">
#  <table>
#   <tr>
#    <th>
#     reżyseria:
#    </th>
#    <td>
#     <ul class="inline sep-comma">
#      <li itemprop="director" itemscope="" itemtype="http://schema.org/Person">
#       <a href="/person/Sam+Taylor+Johnson-79034" itemprop="name" title="Sam Taylor-Johnson">
#        Sam Taylor-Johnson
#       </a>
#      </li>
#     </ul>
#    </td>
#   </tr>
#   <tr>
#    <th>
#     scenariusz:
#    </th>
#    <td>
#     <ul class="inline sep-comma">
#      <li>
#       <a href="/person/Kelly+Marcel-120818" title="Kelly Marcel">
#        Kelly Marcel
#       </a>
#      </li>
#     </ul>
#    </td>
#   </tr>
#   <tr class="hide" data-type="creators" id="voteForCreatorsLabel">
#    <th>
#    </th>
#    <td>
#     <a class="cap voteForCreators" href="#filmCastBox">
#      oceń twórców
#      <i class="roleVoteBtn small">
#      </i>
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <th>
#     gatunek:
#    </th>
#    <td>
# ...

# %%
summary.find(text = "reżyseria:").next_element.text
# Out:
# 'Sam Taylor-Johnson'

# %%
summary.find(text = "scenariusz:").next_element.text
# Out:
# 'Kelly Marcel'

# %%
summary.find(text = "boxoffice:").next_element.contents[0].strip().replace('$', '')
# Out:
# '570 489 358'

# %%
boxoffice = summary.find(text = "boxoffice:").next_element.text
re.findall(r'\$(.*?) top.*', boxoffice)
# Out:
# ['570 489 358']

# %%
#note = soup.find_all(class_ = "box nowrap") #"filmVoteRatingPanelWrapper")
vertical-align
print(note)#.prettify())
# Out:
# [<div class="box nowrap"><div class="plusPanel pull-left" data-etype="Topic" data-id="2618756" data-user="2495447"><span class="plusCount">197</span> <button class="reset btnPlus"><i class="fonti-thumb"></i></button> <button class="reset btnMinus"><i class="fonti-thumb-down"></i></button></div></div>, <div class="box nowrap"><div class="plusPanel pull-left" data-etype="Topic" data-id="2557515" data-user="1629262"><span class="plusCount">134</span> <button class="reset btnPlus"><i class="fonti-thumb"></i></button> <button class="reset btnMinus"><i class="fonti-thumb-down"></i></button></div></div>, <div class="box nowrap"><div class="plusPanel pull-left" data-etype="Topic" data-id="2618976" data-user="1247743"><span class="plusCount">122</span> <button class="reset btnPlus"><i class="fonti-thumb"></i></button> <button class="reset btnMinus"><i class="fonti-thumb-down"></i></button></div></div>, <div class="box nowrap"><div class="plusPanel pull-left" data-etype="Topic" data-id="261485
# ...

# %%
soup.find_all(class_ = "filmMainHeader").find(text="4.5")
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-159-4ce7636557e3> in <module>()
# ----> 1 soup.find_all(class_ = "filmMainHeader").find(text="4.5")
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
soup.find_all(itemprop="ratingValue")[0].text.strip().replace(",", ".")
# Out:
# '4.5'

# %%
zapytanie = "50 twarzy"
p = {
    "q": zapytanie
}
soup = BeautifulSoup(requests.get("https://www.filmweb.pl/films/search", params=p).text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, viewport-fit=cover" name="viewport"/>
#   <meta content="#000000" name="theme-color">
#    <script>
# ...

# %%
link_wzgledny = soup.find_all(class_="filmPreview__link")[0].get("href")
link_wzgledny
# Out:
# '/film/Pi%C4%99%C4%87dziesi%C4%85t+twarzy+Greya-2015-655761'

# %%
adres = "http://www.filmweb.pl" + link_wzgledny
adres
# Out:
# 'http://www.filmweb.pl/film/Pi%C4%99%C4%87dziesi%C4%85t+twarzy+Greya-2015-655761'

# %%
tabela = pd.read_html("http://www.boxofficemojo.com/yearly/chart/?p=.htm&yr=2018")
len(tabela)
# Out:
# 7

# %%
filmy = tabela[5]
filmy.iloc[2:,1:].reset_index(drop=True)
# Out:
#                                         1          2             3     4  \
# 0                           Black Panther         BV  $699,891,993  4084
# 1                  Avengers: Infinity War         BV  $675,568,437  4474
# 2                           Incredibles 2         BV  $524,198,492  4410
# 3          Jurassic World: Fallen Kingdom       Uni.  $352,215,215  4485
# 4                              Deadpool 2        Fox  $315,680,620  4349
# 5                 Solo: A Star Wars Story         BV  $211,627,976  4381
# 6                           A Quiet Place       Par.  $187,557,256  3808
# 7                        Ready Player One         WB  $137,018,455  4234
# 8                               Ocean's 8         WB  $130,185,936  4145
# 9                            Peter Rabbit       Sony  $115,253,424  3725
# 10                   Ant-Man and the Wasp         BV  $112,392,225  4206
# 11                      A Wrinkle in Time         BV  $100,478,608  3980
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Firefox()
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
time.sleep(2)
assert "No results found." not in driver.page_source
driver.close()

# %%
# https://nik.bot.nu/brws.html#list/tag:berserk/

# %%
driver = webdriver.Firefox()
driver.get("https://nik.bot.nu/brws.html#list/tag:berserk/")

SCROLL_PAUSE_TIME = 0.5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

for _ in range(6):
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    # print(new_height)
    # if new_height == last_height:
    #     break
    # last_height = new_height
    
gallery = driver.find_elements_by_class_name("image-block")
driver.close()

# %%
len(gallery)
# Out:
# 133

# %%
driver = webdriver.Firefox()
driver.get("http://sostest.mini.pw.edu.pl/Login")

username = driver.find_element_by_id("username")
password = driver.find_element_by_id("password")

username.send_keys("252087")
password.send_keys("Iw252087")


driver.find_element_by_tag_name("button").click()
driver.get("http://sostest.mini.pw.edu.pl/Student/Scores")
#driver.find_element_by_class_name("btn rounded-btn mx-auto d-block").click()
#driver.close()

# %%
http://sostest.mini.pw.edu.pl/Login
252087 / Iw252087

# %%
<button _ngcontent-c1="" class="btn rounded-btn mx-auto d-block" type="submit">Zaloguj</button>
